# %%
import torch
import torchaudio
import matplotlib.pyplot as plt

# %%
filename = '/home/JulioCesar/test/output.wav'
waveform, sample_rate = torchaudio.load(filename)

# %%
print('Shape of waveform: {}'.format(waveform.size()))
print('Sample rate of waveform: {}'.format(sample_rate))
# Out:
# Shape of waveform: torch.Size([2, 440320])
# Sample rate of waveform: 44100

# %%
type(waveform)
# Out:
# torch.Tensor

# %%
waveform.size()
# Out:
# torch.Size([2, 440320])

# %%
waveform.t().size()
# Out:
# torch.Size([440320, 2])

# %%
plt.figure()
plt.plot(waveform.t().numpy())
# Out:
# [<matplotlib.lines.Line2D at 0x7f0d83e2f3c8>,
#  <matplotlib.lines.Line2D at 0x7f0d83e2f588>]

# %%
plt.figure()
plt.plot(waveform[0].numpy())

# %%
plt.figure()
plt.plot(waveform[1].numpy())

# %%
specgram = torchaudio.transforms.Spectrogram()(waveform)

# %%
print('Shape of spectrogram: {}'.format(specgram.size()))
# Out:
# Shape of spectrogram: torch.Size([2, 201, 2202])

# %%
plt.figure()
plt.imshow(specgram.log2()[0, :, :].numpy(), cmap = 'gray')

# %%
specgram = torchaudio.transforms.MelSpectrogram()(waveform)
print('Shape of spectrogram: {}'.format(specgram.size()))
# Out:
# Shape of spectrogram: torch.Size([2, 128, 2202])

# %%
plt.figure()
p = plt.imshow(specgram.log2()[0,:,:].detach().numpy(), cmap='gray')

# %%
new_sample_rate = sample_rate / 10
print(new_sample_rate)
# Out:
# 4410.0

# %%
channel = 0
transformed = torchaudio.transforms.Resample(sample_rate, new_sample_rate)(waveform[channel,:].view(1,-1))

# %%
print("Shape of transformed waveform: {}".format(transformed.size()))
# Out:
# Shape of transformed waveform: torch.Size([1, 44032])

# %%
plt.figure()
plt.plot(transformed[0,:].numpy())

# %%
channel = 1
transformed = torchaudio.transforms.Resample(sample_rate, new_sample_rate)(waveform[channel,:].view(1,-1))

# %%
print("Shape of transformed waveform: {}".format(transformed.size()))
# Out:
# Shape of transformed waveform: torch.Size([1, 44032])

# %%
print("Min of waveform: {}\nMax of waveform: {}\nMean of waveform: {}".format(waveform.min(), waveform.max(), waveform.mean()))
# Out:
# Min of waveform: -1.0
# Max of waveform: 0.890625
# Mean of waveform: -7.960692164488137e-05

# %%
def normalize(tensor):
    tensor_minusmean = tensor - tensor.mean()
    return tensor_minusmean / tensor_minusmean.abs().max

# %%
transformed = torchaudio.transforms.MuLawEncoding()(waveform)

# %%
print("Shape of transformed waveform: {}".format(transformed.size()))
# Out:
# Shape of transformed waveform: torch.Size([2, 440320])

# %%
plt.figure()
plt.plot(transformed[0,:].numpy())

# %%
reconstructed = torchaudio.transforms.MuLawDecoding()(transformed)

# %%
print("Shape of recovered waveform: {}".format(reconstructed.size()))

plt.figure()
plt.plot(reconstructed[0,:].numpy())
# Out:
# Shape of recovered waveform: torch.Size([2, 440320])

# %%
err = ((waveform-reconstructed).abs() / waveform.abs()).median()

print("Median relative difference between original and MuLaw reconstucted signals: {:.2%}".format(err))
# Out:
# Median relative difference between original and MuLaw reconstucted signals: 1.56%

# %%
mu_law_encoding_waveform = torchaudio.functional.mu_law_encoding(waveform, quantization_channels = 256)

# %%
print("Shape of transformed waveform: {}".format(mu_law_encoding_waveform.size()))
# Out:
# Shape of transformed waveform: torch.Size([2, 440320])

# %%
plt.figure()
plt.plot(mu_law_encoding_waveform[0,:].numpy())

# %%
computed = torchaudio.functional.compute_deltas(specgram.contiguous(), win_length = 3)

# %%
print("Shape of computed deltas: {}".format(computed.shape))
# Out:
# Shape of computed deltas: torch.Size([2, 128, 2202])

# %%
plt.figure()
plt.imshow(computed.log2()[0,:,:].detach().numpy(), cmap='gray')

# %%
gain_waveform = torchaudio.functional.gain(waveform, gain_db=5.0)

# %%
print("Min of gain_waveform: {}\nMax of gain_waveform: {}\nMean of gain_waveform: {}".format(gain_waveform.min(), gain_waveform.max(), gain_waveform.mean()))
# Out:
# Min of gain_waveform: -1.778279423713684
# Max of gain_waveform: 1.5837801694869995
# Mean of gain_waveform: -0.0001415633741999045

# %%
dither_waveform = torchaudio.functional.dither(waveform)
print("Min of dither_waveform: {}\nMax of dither_waveform: {}\nMean of dither_waveform: {}".format(dither_waveform.min(), dither_waveform.max(), dither_waveform.mean()))
# Out:
# Min of dither_waveform: -0.999908447265625
# Max of dither_waveform: 0.890594482421875
# Mean of dither_waveform: -6.491209205705673e-05

# %%
lowpass_waveform = torchaudio.functional.lowpass_biquad(waveform, sample_rate, cutoff_freq=3000)

# %%
print("Min of lowpass_waveform: {}\nMax of lowpass_waveform: {}\nMean of lowpass_waveform: {}".format(lowpass_waveform.min(), lowpass_waveform.max(), lowpass_waveform.mean()))

plt.figure()
plt.plot(lowpass_waveform.t().numpy())
# Out:
# Min of lowpass_waveform: -1.0
# Max of lowpass_waveform: 0.881672203540802
# Mean of lowpass_waveform: -7.878529868321493e-05
# [<matplotlib.lines.Line2D at 0x7f0d7fd7b828>,
#  <matplotlib.lines.Line2D at 0x7f0d7fd7b978>]

# %%
highpass_waveform = torchaudio.functional.highpass_biquad(waveform, sample_rate, cutoff_freq=2000)

print("Min of highpass_waveform: {}\nMax of highpass_waveform: {}\nMean of highpass_waveform: {}".format(highpass_waveform.min(), highpass_waveform.max(), highpass_waveform.mean()))

plt.figure()
plt.plot(highpass_waveform.t().numpy())
# Out:
# Min of highpass_waveform: -0.22151315212249756
# Max of highpass_waveform: 0.18934836983680725
# Mean of highpass_waveform: 1.2368450708066803e-09
# [<matplotlib.lines.Line2D at 0x7f0d7fd365f8>,
#  <matplotlib.lines.Line2D at 0x7f0d7fd36748>]

# %%
n_fft = 400.0
frame_length = n_fft / sample_rate * 1000.0
frame_shift = frame_length / 2.0

params = {
    "channel": 0,
    "dither": 0.0,
    "window_type": "hanning",
    "frame_length": frame_length,
    "frame_shift": frame_shift,
    "remove_dc_offset": False,
    "round_to_power_of_two": False,
    "sample_frequency": sample_rate,
}

specgram = torchaudio.compliance.kaldi.spectrogram(waveform, **params)

print("Shape of spectrogram: {}".format(specgram.size()))

plt.figure()
plt.imshow(specgram.t().numpy(), cmap='gray')
# Out:
# Shape of spectrogram: torch.Size([2200, 201])

# %%
fbank = torchaudio.compliance.kaldi.fbank(waveform, **params)

print("Shape of fbank: {}".format(fbank.size()))

plt.figure()
plt.imshow(fbank.t().numpy(), cmap='gray')
# Out:
# Shape of fbank: torch.Size([2200, 23])

# %%
mfcc = torchaudio.compliance.kaldi.mfcc(waveform, **params)

print("Shape of mfcc: {}".format(mfcc.size()))

plt.figure()
plt.imshow(mfcc.t().numpy(), cmap='gray')
# Out:
# Shape of mfcc: torch.Size([2200, 13])

# %%
yesno_data = torchaudio.datasets.YESNO('./', download=True)
# Out:
# 100.0%

# %%
len(yesno_data)
# Out:
# 60

# %%
type(yesno_data)
# Out:
# torchaudio.datasets.yesno.YESNO

# %%
n = 3
waveform, sample_rate, labels = yesno_data[n]

# %%
print("Waveform: {}\nSample rate: {}\nLabels: {}".format(waveform, sample_rate, labels))

plt.figure()
plt.plot(waveform.t().numpy())
# Out:
# Waveform: tensor([[3.0518e-05, 6.1035e-05, 3.0518e-05,  ..., 4.5776e-04, 4.5776e-04,
#          1.1292e-03]])
# Sample rate: 8000
# Labels: [1, 1, 1, 0, 0, 1, 0, 1]
